# %% [markdown]
# ---
# title: "Calibration Risk in Costly Mean-Reversion Trading"
# date: 2026-04-30
# description: "Studies how OU parameter uncertainty affects cost-adjusted half-life, no-trade bands, leverage, and tail estimates."
# categories: [Quantitative Finance, Mean Reversion, Trading Strategy]
# content-type: "series"
# series-id: "mean-reversion-strategy"
# series-title: "Expected Performance of a Mean-Reversion Trading Strategy"
# series-part: 11
# project-ids: [mean-reversion-strategy]
# ---
#
# ## Outline
# - Discrete OU likelihood
# - Mean-estimation bias
# - Speed-estimation uncertainty
# - Robust policy selection
# - Calibration diagnostics

# %%
# Scratchpad
import numpy as np
import pandas as pd
