# %% [markdown]
# ---
# title: "Transaction Costs in a Discrete EWM Mean-Reversion Strategy"
# date: 2026-04-30
# description: "Derives turnover, expected transaction costs, net PnL, and break-even costs for exact EWM target tracking."
# categories: [Quantitative Finance, Mean Reversion, Trading Strategy]
# content-type: "series"
# series-id: "mean-reversion-strategy"
# series-title: "Expected Performance of a Mean-Reversion Trading Strategy"
# series-part: 8
# project-ids: [mean-reversion-strategy]
# ---
#
# ## Outline
# - Exact target tracking
# - Expected turnover
# - Net mean and break-even cost
# - Net distribution
# - Cost formulas

# %%
# Scratchpad
import numpy as np
import pandas as pd
