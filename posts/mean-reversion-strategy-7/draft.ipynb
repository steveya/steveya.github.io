# %% [markdown]
# ---
# title: "The Tail Shape of Mean-Reversion P&L: Frequent Small Gains, Occasional Large Losses?"
# date: 2026-04-24
# description: "Studies the eigenvalue-driven tail asymmetry and quantiles of cumulative mean-reversion P&L."
# categories: [Quantitative Finance, Mean Reversion, Trading Strategy]
#
# ---
#
# ## Outline
# - Motivation
# - Data
# - Method
# - Results
# - Notes / TODO

# %%
# Scratchpad
import numpy as np
import pandas as pd
