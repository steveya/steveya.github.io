# %% [markdown]
# ---
# title: "When Fair Value Moves: Signal Extraction versus Mean Reversion"
# date: 2026-04-30
# description: "Extends the framework to latent moving fair value and separates signal extraction from mean reversion."
# categories: [Quantitative Finance, Mean Reversion, Trading Strategy]
# content-type: "series"
# series-id: "mean-reversion-strategy"
# series-title: "Expected Performance of a Mean-Reversion Trading Strategy"
# series-part: 12
# project-ids: [mean-reversion-strategy]
# ---
#
# ## Outline
# - Latent fair-value model
# - Observed price decomposition
# - EWM signal extraction
# - Half-life tradeoff
# - Stress tests

# %%
# Scratchpad
import numpy as np
import pandas as pd
