# %% [markdown]
# ---
# title: "Testing the Cost-Aware Mean-Reversion Framework: Simulated OU and Real Spreads"
# date: 2026-04-30
# description: "Runs a calibrated or empirical end-to-end test of the cost-aware mean-reversion framework."
# categories: [Quantitative Finance, Mean Reversion, Trading Strategy]
# content-type: "series"
# series-id: "mean-reversion-strategy"
# series-title: "Expected Performance of a Mean-Reversion Trading Strategy"
# series-part: 13
# project-ids: [mean-reversion-strategy]
# ---
#
# ## Outline
# - Calibrated simulation
# - OU fit
# - Cost-aware half-life
# - Policy comparison
# - Net PnL and tail metrics

# %%
# Scratchpad
import numpy as np
import pandas as pd
