# %% [markdown]
# ---
# title: "The Optimal EWM Half-Life for a Mean-Reversion Strategy under Transaction Costs"
# date: 2026-04-30
# description: "Optimizes the EWM persistence and half-life under transaction costs and OU mean-reversion speed."
# categories: [Quantitative Finance, Mean Reversion, Trading Strategy]
# content-type: "series"
# series-id: "mean-reversion-strategy"
# series-title: "Expected Performance of a Mean-Reversion Trading Strategy"
# series-part: 9
# project-ids: [mean-reversion-strategy]
# ---
#
# ## Outline
# - Net objective
# - Half-life parameterization
# - Asymptotic regimes
# - Sensitivity surfaces
# - Practical selection rule

# %%
# Scratchpad
import numpy as np
import pandas as pd
