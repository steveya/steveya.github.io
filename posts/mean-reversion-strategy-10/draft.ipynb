# %% [markdown]
# ---
# title: "Trading Mean Reversion with Costs: No-Trade Bands, Position Caps, and Tail Control"
# date: 2026-04-30
# description: "Compares exact target tracking with no-trade bands, thresholds, position caps, and tail-aware objectives."
# categories: [Quantitative Finance, Mean Reversion, Trading Strategy]
# content-type: "series"
# series-id: "mean-reversion-strategy"
# series-title: "Expected Performance of a Mean-Reversion Trading Strategy"
# series-part: 10
# project-ids: [mean-reversion-strategy]
# ---
#
# ## Outline
# - Frictionless target vs actual position
# - No-trade bands
# - Signal thresholds
# - Position caps
# - Tail-aware objectives
# - Policy comparison

# %%
# Scratchpad
import numpy as np
import pandas as pd
